# %% [markdown]
# # CapStone Project : Topic modeling on Amazon customer support

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Amazon is the one of the world's biggest e-commerce platform. Apart from its own platform, Amazon has different channels of customer support. Twitter is one of them. Amazon has a customer suport account on Twitter called @Amazonhlep. It is not surprise that the volume of customer requests is huge. In 2017 , there are nearly 100K tweets on AmazonHelp. With such a high volume, maintaining the quality of the customer support would be challenging.
#
# This project aim at having a better allocation of customer support workforce by identifying the intent of customer. The intention of customer will be categorized into different topics and then we can restructure the customer support team into sub team based on these topics.  Ultimately, to triage and route the customer support reqeusts to appropriate sub team in order to provide a more efficient customer support.

# %% [markdown]
# ## Exective Summary

# %% [markdown]
# No business can survive without customers. This reflects on the mission of Amazon, one of the world's biggest e-commerce platform, “to be Earth’s most customer-centric company" and the award-winning Customer Service team is an essential part of this mission. This is why maintaining the quality of the customer support is crucial to Amazon.
#
# ### why Twitter?
# Firstly, Twitter can be a big showcase for Amazon customer support. It is a globally well known social media platform and it had more than 321 million monthly active users as of 2018. Unlike Amazon 's own customer support platform,  everyone can see other people's complaints or requests on AmazonHelp (Amazon's customer support on Twitter). Because Twitter's primary purpose is to connect people and allow people to share their thoughts with a big audience.If we can provide good quality and efficient customer support,it also facilitates to positive brand image.
#
# Secondly, Twitter aims to create highly skimmable content for our tech-heavy, attention-deficit modern world. Thus, Tweets can be only up to 140 characters long. The short conversation is similar to live chat. Users contact customer support to have a specific problem solved, and the manifold of problems to be discussed is relatively small, especially compared to unconstrained conversational datasets like the reddit Corpus. Understanding the tweets pattern helps us to understand the talking pattern of the users nowaday. And this project explores Twitter as a pioneer project. We can start from Twitter first and then explore to other customer support platform such as Facebook, email.
#
# ### Key findings
#
# 1. Presence of non English tweets such as Japanese, Spanish, German as AmazonHelp support foreign languages.
# 2. spam tweets, a single users contribute to 417 tweets alone. The tweets accross 2015-2017
# 3. 99% of the tweets are requested in 2017
# 4. Oct,Nov and Dec has the most tweets. prioritize these three months.
# 5. The SLA(Service Level Agreement) of AmazonHelp is around 13 mins.It can be the baseline of SLA. And when the tweet volumn are high in Oct, Nov and Dec. The SLA should be shorter than 13 mins.
#
# ### Dataset__
# The dataset `Customer Support on Twitter` is from Kaggle (https://www.kaggle.com/thoughtvector/customer-support-on-twitter). It offers a large corpus of modern English (mostly) conversations between consumers and customer support agents on Twitter.
#
# The dataset consists of the tweets refer to 108 different companies. AmazonHelp has the highest number of tweets. In this project, I will only focus on @AmazonHelp 's tweets.
#
# ### Conclusion and Recommendation
# LDA helped to categorize 3 main topics, they are inferred to be :
#
# Topic 1 : Carrier - especially with USPS (Postal service company of United States)
#
# Topic 2 : account issue - email follow up
#
# Topic 3 : delivery - with Prime account
#
# ### Recommendation :
# To restructure the customer support team into sub team based on these 3 topics.
# For example, we can have a sub team dealing with carrier issue and espceially keep an eye on USPS. The second team will be responsible for incoming emails. The third team will be dealing with Prime account. And the peak season is in Oct, Nov and Dec, be aware of the allocation of staffs and the SLA.

# %%
import re
import pandas as pd
import numpy as np
import string
from langdetect import detect

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

from termcolor import colored

# %% [markdown]
# # Import the dataset

# %%
all_twitter = pd.read_csv('./datasets/twcs.csv')

# %% [markdown]
# # First glance of the dataset

# %%
# Define function for basic eda

def data_explore(df):
    #First two rows
    print("First five rows of data:")
    display(df.head())
    print()
    # Print shape of dataframe
    print(colored(f"Shape: {df.shape}",'blue',attrs=['bold']))
    print()
    # Print datatypes
    print(colored("Columns & Datatypes: ",'blue',attrs=['bold']))
    df.info()
    print()
    # Check for null values
    print(colored("Null values:",'blue',attrs=['bold']))
    if df.isnull().values.any() == False:
        print("None in Dataframe.")
    else:
        for col in df:
            print(f"{col}:{df[col].isnull().sum()}")
    print()
    # Count of distinct values
    print(colored("Unique values (by Columns)",'blue',attrs=['bold']))
    for col in df:
        print(f"{col}:{len(df[col].unique().tolist())}")

# %%
data_explore(all_twitter)
# Out:
# First five rows of data:
#    tweet_id   author_id  inbound                      created_at  \
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @115712 I understand. I would like to assist y...                 2
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# 4                      6.0
# Shape: (2811774, 7)
#
# Columns & Datatypes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2811774 entries, 0 to 2811773
# Data columns (total 7 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tweet_id                 int64
#  1   author_id                object
#  2   inbound                  bool
#  3   created_at               object
#  4   text                     object
#  5   response_tweet_id        object
#  6   in_response_to_tweet_id  float64
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 131.4+ MB
#
# Null values:
# tweet_id:0
# author_id:0
# inbound:0
# created_at:0
# text:0
# response_tweet_id:1040629
# in_response_to_tweet_id:794335
#
# Unique values (by Columns)
# tweet_id:2811774
# author_id:702777
# inbound:2
# created_at:2061666
# text:2782618
# response_tweet_id:1771146
# in_response_to_tweet_id:1774823

# %% [markdown]
# # Examine dataset structure - Inbound and Response Tweets

# %% [markdown]
# In this section, I will get the data into a shape that's useful for further explorations: first consumer messages to companies, and their response.
# Starter code below is from the Customer Support on Twitter dataset creator :
# retrieved from https://www.kaggle.com/soaxelbrooke/first-inbound-and-response-tweets

# %%
# Pick only inbound tweets that aren't in reply to anything...
first_inbound = all_twitter[pd.isnull(all_twitter.in_response_to_tweet_id) & all_twitter.inbound]
print('Found {} first inbound messages.'.format(len(first_inbound)))

# Merge in all tweets in response
inbounds_and_outbounds = pd.merge(first_inbound, all_twitter, left_on='tweet_id', 
                                  right_on='in_response_to_tweet_id')
print("Found {} responses.".format(len(inbounds_and_outbounds)))


# Filter out cases where reply tweet isn't from company
inbounds_and_outbounds = inbounds_and_outbounds[inbounds_and_outbounds.inbound_y ^ True]

# print the finding
print("Found {} responses from companies.".format(len(inbounds_and_outbounds)))
print("Tweets Preview:")
print(inbounds_and_outbounds)
# Out:
# Found 787346 first inbound messages.
# Found 875292 responses.
# Found 794299 responses from companies.
# Tweets Preview:
#         tweet_id_x author_id_x  inbound_x                    created_at_x  \
# 0                8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 1                8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 2                8      115712       True  Tue Oct 31 21:45:10 +0000 2017
# 3               18      115713       True  Tue Oct 31 19:56:01 +0000 2017
# 4               20      115715       True  Tue Oct 31 22:03:34 +0000 2017
# ...            ...         ...        ...                             ...
# 875287     2987942      823867       True  Wed Nov 22 07:30:39 +0000 2017
# 875288     2987944      823868       True  Wed Nov 22 07:43:36 +0000 2017
# 875289     2987946      524544       True  Wed Nov 22 08:25:48 +0000 2017
# 875290     2987948      823869       True  Wed Nov 22 08:35:16 +0000 2017
# 875291     2987950      823870       True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                    text_x response_tweet_id_x  \
# 0               @sprintcare is the worst customer service              9,6,10
# 1               @sprintcare is the worst customer service              9,6,10
# 2               @sprintcare is the worst customer service              9,6,10
# 3       @115714 y’all lie about your “great” connectio...                  17
# 4       @115714 whenever I contact customer support, t...                  19
# ...                                                   ...                 ...
# 875287  Hai @AirAsiaSupport #asking how many days need...             2987941
# 875288  @AirAsiaSupport \n\nI am unable to do web chec...             2987943
# 875289  @VirginTrains Hope you are well? Does the 9.30...             2987945
# 875290  @115714 wtf!? I’ve been having really shitty s...             2987947
# 875291  @AldiUK  warm sloe gin mince pies with ice cre...     2987951,2987949
#
#         in_response_to_tweet_id_x  tweet_id_y     author_id_y  inbound_y  \
# 0                             NaN           6      sprintcare      False
# 1                             NaN           9      sprintcare      False
# 2                             NaN          10      sprintcare      False
# 3                             NaN          17      sprintcare      False
# 4                             NaN          19      sprintcare      False
# ...                           ...         ...             ...        ...
# 875287                        NaN     2987941  AirAsiaSupport      False
# 875288                        NaN     2987943  AirAsiaSupport      False
# 875289                        NaN     2987945    VirginTrains      False
# 875290                        NaN     2987947      sprintcare      False
# 875291                        NaN     2987949          AldiUK      False
#
#                           created_at_y  \
# 0       Tue Oct 31 21:46:24 +0000 2017
# 1       Tue Oct 31 21:46:14 +0000 2017
# 2       Tue Oct 31 21:45:59 +0000 2017
# 3       Tue Oct 31 19:59:13 +0000 2017
# 4       Tue Oct 31 22:10:10 +0000 2017
# ...                                ...
# 875287  Wed Nov 22 07:55:05 +0000 2017
# 875288  Wed Nov 22 07:54:57 +0000 2017
# 875289  Wed Nov 22 08:27:34 +0000 2017
# 875290  Wed Nov 22 08:43:51 +0000 2017
# 875291  Wed Nov 22 08:31:24 +0000 2017
#
#                                                    text_y response_tweet_id_y  \
# 0       @115712 Can you please send us a private messa...                 5,7
# 1       @115712 I would love the chance to review the ...                 NaN
# 2       @115712 Hello! We never like our customers to ...                 NaN
# 3       @115713 H there! We'd definitely like to work ...                  16
# 4       @115715 Please send me a private message so th...                 NaN
# ...                                                   ...                 ...
# 875287     @823867 we have replied you via DM.Thanks-Emir                 NaN
# 875288  @823868 Sorry but kindly try to clear browser,...                 NaN
# 875289  @524544 That's a Peak service. The 09:56 is th...                 NaN
# 875290  @823869 Hey, we'd be happy to look into this f...                 NaN
# 875291  @823870 Sounds delicious, Sarah! 😋 https://t.c...                 NaN
#
#         in_response_to_tweet_id_y
# 0                             8.0
# 1                             8.0
# 2                             8.0
# 3                            18.0
# 4                            20.0
# ...                           ...
# 875287                  2987942.0
# 875288                  2987944.0
# 875289                  2987946.0
# 875290                  2987948.0
# 875291                  2987950.0
#
# [794299 rows x 14 columns]

# %% [markdown]
# Short Summary from above :
#
# In this dataset, there are 787346 first inbound messages. These are tweets that aren't in reply to anything.
# And 794299 responses are from companies among the 875292 responses tweets.
#
# We can see from the authod_id that there are other companies'customer support tweeter accounts like 'sprintcare' and 'AirAsiaSupport'. In this project, I will only focus on Amazon's tweeter account named 'AmazonHelp'.
#
# columns `in_response_to_tweet_id_x` and `response_tweet_id_y` have missing values. In this project, I will not need these columns. I will drop the response tweet id related columns.

# %%
#I will need the request from the tweeter users and response from AmazonHelp
amazon_tweets = inbounds_and_outbounds \
    .loc[inbounds_and_outbounds.author_id_y == 'AmazonHelp']

# %%
#reset the index of the new dateframe 
amazon_tweets = amazon_tweets.reset_index(drop=True)

# %%
#There are non-english tweets as AmazonHelp also support languages 
data_explore(amazon_tweets)
# Out:
# First five rows of data:
#    tweet_id_x author_id_x  inbound_x                    created_at_x  \
# 0         272      115770       True  Wed Nov 22 09:14:39 +0000 2017
# 1         325      115792       True  Wed Nov 22 08:55:35 +0000 2017
# 2         617      115820       True  Tue Oct 31 22:16:32 +0000 2017
# 3         621      115822       True  Tue Oct 31 22:19:34 +0000 2017
# 4         624      115824       True  Tue Oct 31 22:12:37 +0000 2017
#
#                                               text_x response_tweet_id_x  \
# 0                           amazonのfireTVstickが見れない😢                 269
# 1                           amazonプライムビデオ、再生エラーが多いです                 324
# 2  Way to drop the ball on customer service @1158...                 615
# 3  @115823 I want my amazon payments account CLOS...                 620
# 4  @115825 also, beim Addams Family-Film in Prime...                 622
#
#    in_response_to_tweet_id_x  tweet_id_y author_id_y  inbound_y  \
# 0                        NaN         269  AmazonHelp      False
# 1                        NaN         324  AmazonHelp      False
# 2                        NaN         615  AmazonHelp      False
# 3                        NaN         620  AmazonHelp      False
# 4                        NaN         622  AmazonHelp      False
#
#                      created_at_y  \
# 0  Wed Nov 22 09:23:01 +0000 2017
# 1  Wed Nov 22 09:06:00 +0000 2017
# 2  Tue Oct 31 22:29:00 +0000 2017
# 3  Tue Oct 31 22:28:34 +0000 2017
# 4  Tue Oct 31 22:28:00 +0000 2017
#
#                                               text_y response_tweet_id_y  \
# 0  @115770 こんにちは、アマゾン公式です。Fire TV Stickが見れないというのは...             270,271
# 1  @115792 ご不便をおかけしております。アプリをご利用でしょうか。強制停止&gt;端末の...                 NaN
# 2  @115820 I'm sorry we've let you down! Without ...                 616
# 3  @115822 I am unable to affect your account via...                 NaN
# 4  @115824 Hi, wir erhalten die Filme/Serien so v...                 623
#
#    in_response_to_tweet_id_y
# 0                      272.0
# 1                      325.0
# 2                      617.0
# 3                      621.0
# 4                      624.0
# Shape: (84637, 14)
#
# Columns & Datatypes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84637 entries, 0 to 84636
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   tweet_id_x                 84637 non-null  int64
#  1   author_id_x                84637 non-null  object
#  2   inbound_x                  84637 non-null  bool
#  3   created_at_x               84637 non-null  object
#  4   text_x                     84637 non-null  object
#  5   response_tweet_id_x        84637 non-null  object
#  6   in_response_to_tweet_id_x  0 non-null      float64
#  7   tweet_id_y                 84637 non-null  int64
#  8   author_id_y                84637 non-null  object
#  9   inbound_y                  84637 non-null  bool
#  10  created_at_y               84637 non-null  object
#  11  text_y                     84637 non-null  object
#  12  response_tweet_id_y        41190 non-null  object
#  13  in_response_to_tweet_id_y  84637 non-null  float64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 7.9+ MB
#
# Null values:
# tweet_id_x:0
# author_id_x:0
# inbound_x:0
# created_at_x:0
# text_x:0
# response_tweet_id_x:0
# in_response_to_tweet_id_x:84637
# tweet_id_y:0
# author_id_y:0
# inbound_y:0
# created_at_y:0
# text_y:0
# response_tweet_id_y:43447
# in_response_to_tweet_id_y:0
#
# Unique values (by Columns)
# tweet_id_x:76799
# author_id_x:65599
# inbound_x:1
# created_at_x:76163
# text_x:76749
# response_tweet_id_x:76799
# in_response_to_tweet_id_x:1
# tweet_id_y:84637
# author_id_y:1
# inbound_y:1
# created_at_y:70388
# text_y:84632
# response_tweet_id_y:41191
# in_response_to_tweet_id_y:76799

# %% [markdown]
# ### Dilemma : Should I focus on the request from the user or should I include the response tweets from AmazonHelp?

# %%
# Let's see the request from the user 
#I will need the request from the tweeter users to the AmazonHelp
amazon_request = all_twitter.loc[(all_twitter.inbound==True)& (all_twitter.text.str.contains('@AmazonHelp'))]

# %%
#reset the index of the new dateframe 
amazon_request=amazon_request.reset_index(drop=True)

# %%
#fisrt glance of the dataframe
data_explore(amazon_request)
# Out:
# First five rows of data:
#    tweet_id author_id  inbound                      created_at  \
# 0       270    115770     True  Wed Nov 22 09:24:30 +0000 2017
# 1       271    115770     True  Wed Nov 22 09:30:36 +0000 2017
# 2       274    115770     True  Wed Nov 22 09:44:04 +0000 2017
# 3       616    115820     True  Tue Oct 31 23:22:08 +0000 2017
# 4       619    115820     True  Tue Oct 31 23:32:26 +0000 2017
#
#                                                 text response_tweet_id  \
# 0      @AmazonHelp ありがとうございます。\n今、電話で主人が対応していただいてます。               NaN
# 1  @AmazonHelp 電話で対応してもらいましたが改良されませんでした。\n保証期間も過ぎ...               273
# 2                      @AmazonHelp こちらこそありがとうございました。               275
# 3  @AmazonHelp 3 different people have given 3 di...               618
# 4  @AmazonHelp I frankly don't have the patience ...               NaN
#
#    in_response_to_tweet_id
# 0                    269.0
# 1                    269.0
# 2                    273.0
# 3                    615.0
# 4                    618.0
# Shape: (134725, 7)
#
# Columns & Datatypes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134725 entries, 0 to 134724
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tweet_id                 134725 non-null  int64
#  1   author_id                134725 non-null  object
#  2   inbound                  134725 non-null  bool
#  3   created_at               134725 non-null  object
#  4   text                     134725 non-null  object
#  5   response_tweet_id        99765 non-null   object
#  6   in_response_to_tweet_id  112744 non-null  float64
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 6.3+ MB
#
# Null values:
# tweet_id:0
# author_id:0
# inbound:0
# created_at:0
# text:0
# response_tweet_id:34960
# in_response_to_tweet_id:21981
#
# Unique values (by Columns)
# tweet_id:134725
# author_id:48044
# inbound:1
# created_at:132751
# text:131142
# response_tweet_id:99766
# in_response_to_tweet_id:96669

# %% [markdown]
# My decision :
#
# Now I have two dataframe :
#
# 1.`amazon_tweets` which combine the user request and amazon's response
#
# 2.`amazon_request` which only includes the user request
#
# After examine the dataframes, I decide to use amazon_requests since my goal is to build a topic modelling to triage the user request. I am interested to understand the intent of the customer.
# Also, the shape of amazon_requests are much larger(amazon_requests has 134725 rows and amazon_tweets has 84637 rows.)
# I would like to have a larger dataset for my modelling.
#
# Thus, I will use amazon_request dataframe from now on.

# %%
#I will not need the response tweet ids. dropped the response tweet id related columns
amazon_request = amazon_request.drop(['response_tweet_id', 'in_response_to_tweet_id'],axis=1)

# %%
#ensure the columns are dropped
amazon_request.head()
# Out:
#    tweet_id author_id  inbound                      created_at  \
# 0       270    115770     True  Wed Nov 22 09:24:30 +0000 2017
# 1       271    115770     True  Wed Nov 22 09:30:36 +0000 2017
# 2       274    115770     True  Wed Nov 22 09:44:04 +0000 2017
# 3       616    115820     True  Tue Oct 31 23:22:08 +0000 2017
# 4       619    115820     True  Tue Oct 31 23:32:26 +0000 2017
#
#                                                 text
# 0      @AmazonHelp ありがとうございます。\n今、電話で主人が対応していただいてます。
# 1  @AmazonHelp 電話で対応してもらいましたが改良されませんでした。\n保証期間も過ぎ...
# 2                      @AmazonHelp こちらこそありがとうございました。
# 3  @AmazonHelp 3 different people have given 3 di...
# 4  @AmazonHelp I frankly don't have the patience ...

# %% [markdown]
# ## Filter out non english tweet

# %% [markdown]
# Afer looking into the dataset , we can see that there are non-english tweets as AmazonHelp also support languages
# In this section, I will filter out the non english tweets. I will only examine the english tweet in this project.

# %%
#create a small subset of data for debug and test the function of filtering non english tweet
#i.e shorter running time 
amazon_sample = amazon_request.head(100)

# %%
#make sure this sample dataframe contains non english tweet 
amazon_sample.head(40)
# Out:
#     tweet_id author_id  inbound                      created_at  \
# 0        270    115770     True  Wed Nov 22 09:24:30 +0000 2017
# 1        271    115770     True  Wed Nov 22 09:30:36 +0000 2017
# 2        274    115770     True  Wed Nov 22 09:44:04 +0000 2017
# 3        616    115820     True  Tue Oct 31 23:22:08 +0000 2017
# 4        619    115820     True  Tue Oct 31 23:32:26 +0000 2017
# 5        623    115824     True  Tue Oct 31 22:32:07 +0000 2017
# 6        627    115827     True  Wed Nov 01 12:50:18 +0000 2017
# 7        634    115831     True  Tue Oct 31 21:39:58 +0000 2017
# 8        638    115834     True  Tue Oct 31 22:19:56 +0000 2017
# 9        640    115834     True  Tue Oct 31 01:03:01 +0000 2017
# 10       641    115834     True  Tue Oct 31 01:02:39 +0000 2017
# 11       643    115834     True  Mon Oct 30 23:44:45 +0000 2017
# 12       645    115835     True  Wed Nov 01 08:04:52 +0000 2017
# 13       646    115835     True  Tue Oct 31 21:40:30 +0000 2017
# 14       651    115838     True  Tue Oct 31 22:25:58 +0000 2017
# 15       654    115838     True  Tue Oct 31 22:53:50 +0000 2017
# 16       652    115838     True  Tue Oct 31 22:11:15 +0000 2017
# 17       657    115839     True  Tue Oct 31 22:18:42 +0000 2017
# 18       664    115842     True  Tue Oct 31 21:50:49 +0000 2017
# 19       666    115843     True  Wed Nov 01 01:26:58 +0000 2017
# 20       669    115844     True  Tue Oct 31 22:21:12 +0000 2017
# 21       685    115849     True  Wed Nov 01 05:26:45 +0000 2017
# 22       686    115849     True  Tue Oct 31 22:06:53 +0000 2017
# 23       690    115849     True  Tue Oct 31 21:45:15 +0000 2017
# 24       693    115852     True  Tue Oct 31 22:10:21 +0000 2017
# 25      1693    116081     True  Tue Oct 31 22:54:54 +0000 2017
# 26      1694    116081     True  Tue Oct 31 22:54:29 +0000 2017
# 27      1698    116082     True  Tue Oct 31 22:47:50 +0000 2017
# 28      1701    116082     True  Tue Oct 31 22:58:06 +0000 2017
# 29      1702    116082     True  Tue Oct 31 23:00:14 +0000 2017
# 30      1703    116082     True  Tue Oct 31 22:59:37 +0000 2017
# 31      1699    116082     True  Tue Oct 31 22:34:38 +0000 2017
# 32      1706    116083     True  Tue Oct 31 22:33:08 +0000 2017
# 33      1710    116084     True  Tue Oct 31 22:33:35 +0000 2017
# 34      1712    116085     True  Tue Oct 31 22:46:48 +0000 2017
# 35      1713    116085     True  Tue Oct 31 21:21:34 +0000 2017
# 36      1717    116087     True  Tue Oct 31 22:40:54 +0000 2017
# 37      1721    116088     True  Tue Oct 31 22:37:35 +0000 2017
# 38      1724    116088     True  Tue Oct 31 22:48:50 +0000 2017
# 39      1726    116088     True  Tue Oct 31 23:05:46 +0000 2017
#
#                                                  text
# 0       @AmazonHelp ありがとうございます。\n今、電話で主人が対応していただいてます。
# 1   @AmazonHelp 電話で対応してもらいましたが改良されませんでした。\n保証期間も過ぎ...
# 2                       @AmazonHelp こちらこそありがとうございました。
# 3   @AmazonHelp 3 different people have given 3 di...
# 4   @AmazonHelp I frankly don't have the patience ...
# 5                @AmazonHelp Okay, danke für die Info
# 6   @AmazonHelp @115826 Yeah this is crazy we’re l...
# 7   @115821 @AmazonHelp why is my order at my loca...
# 8                  @AmazonHelp Hi ready for some help
# 9   @AmazonHelp Is the Echo Show no longer supported?
# 10  @AmazonHelp Nothing there helped me with the E...
# 11  Bought an @115821 Echo Show and it won’t recog...
# 12  @AmazonHelp That page is useless - doesn’t all...
# 13  .@AmazonHelp Item has not been delivered but t...
# 14  @AmazonHelp I don't want a form to fill out th...
# 15  @AmazonHelp Already started the return. UPS ge...
# 16  @AmazonHelp Is it possible to prevent AMZL fro...
# 17  @AmazonHelp Already handled, just venting. It ...
# 18  @AmazonHelp delivery I paid for today,didn’t a...
# 19         @AmazonHelp Aww your reply made her night!
# 20  @AmazonHelp I just said it's been sorted! I've...
# 21            @AmazonHelp Details sent. Please check.
# 22  @AmazonHelp Already contacted 3-4 times in the...
# 23  @115850 @115821 @AmazonHelp @115851 Order# 363...
# 24  @AmazonHelp since when you stop giving 20% off...
# 25  @AmazonHelp but I can’t find the options to ca...
# 26  @AmazonHelp Thanks for quick response. Pic att...
# 27  @AmazonHelp Thats the thing I told customer se...
# 28  @AmazonHelp You have to log in. I don't rememb...
# 29  @AmazonHelp They sent me the email I sent you ...
# 30  @AmazonHelp I tried my phone number but I didn...
# 31  @AmazonHelp I called customer service and was ...
# 32  @AmazonHelp I have tried. It’s not allowing me...
# 33  @AmazonHelp where can I chat with a support me...
# 34  @AmazonHelp So essentially still two separate ...
# 35  @AmazonHelp if I add another adult to my Amazo...
# 36  @AmazonHelp My package just got here. All good...
# 37  @AmazonHelp Never got the beta and now I’m bei...
# 38  @AmazonHelp Deluxe edition on September 16th. ...
# 39  @AmazonHelp Star Wars Battlefront 2 Elite Troo...

# %% [markdown]
# ### Filter non English tweet - Test on subset (first 100 tweets)

# %%
#use for loor to filiter out every non english tweet on Amazon
#fliter non english on the sample data

y = 0
for _ in amazon_sample['text']:
    if re.search('[^\x00-\x7F]',amazon_sample['text'][y]) == None:    # [^\x00-\x7F] is to filter non ascii 
        y = y+1
    else:
        amazon_sample.drop(index = y, inplace = True)
        y = y+1 
        continue
amazon_sample.reset_index(drop=True, inplace=True)
# Out:
# /Users/mpc/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
amazon_sample
# Out:
#     tweet_id author_id  inbound                      created_at  \
# 0        616    115820     True  Tue Oct 31 23:22:08 +0000 2017
# 1        619    115820     True  Tue Oct 31 23:32:26 +0000 2017
# 2        638    115834     True  Tue Oct 31 22:19:56 +0000 2017
# 3        640    115834     True  Tue Oct 31 01:03:01 +0000 2017
# 4        641    115834     True  Tue Oct 31 01:02:39 +0000 2017
# 5        646    115835     True  Tue Oct 31 21:40:30 +0000 2017
# 6        651    115838     True  Tue Oct 31 22:25:58 +0000 2017
# 7        654    115838     True  Tue Oct 31 22:53:50 +0000 2017
# 8        652    115838     True  Tue Oct 31 22:11:15 +0000 2017
# 9        657    115839     True  Tue Oct 31 22:18:42 +0000 2017
# 10       666    115843     True  Wed Nov 01 01:26:58 +0000 2017
# 11       669    115844     True  Tue Oct 31 22:21:12 +0000 2017
# 12       685    115849     True  Wed Nov 01 05:26:45 +0000 2017
# 13       686    115849     True  Tue Oct 31 22:06:53 +0000 2017
# 14       690    115849     True  Tue Oct 31 21:45:15 +0000 2017
# 15       693    115852     True  Tue Oct 31 22:10:21 +0000 2017
# 16      1694    116081     True  Tue Oct 31 22:54:29 +0000 2017
# 17      1698    116082     True  Tue Oct 31 22:47:50 +0000 2017
# 18      1701    116082     True  Tue Oct 31 22:58:06 +0000 2017
# 19      1702    116082     True  Tue Oct 31 23:00:14 +0000 2017
# 20      1703    116082     True  Tue Oct 31 22:59:37 +0000 2017
# 21      1699    116082     True  Tue Oct 31 22:34:38 +0000 2017
# 22      1710    116084     True  Tue Oct 31 22:33:35 +0000 2017
# 23      1713    116085     True  Tue Oct 31 21:21:34 +0000 2017
# 24      1717    116087     True  Tue Oct 31 22:40:54 +0000 2017
# 25      1726    116088     True  Tue Oct 31 23:05:46 +0000 2017
# 26      1729    116088     True  Tue Oct 31 23:54:43 +0000 2017
# 27      1738    116091     True  Tue Oct 31 22:47:44 +0000 2017
# 28      1736    116091     True  Tue Oct 31 22:21:42 +0000 2017
# 29      1740    116092     True  Sat Nov 04 00:53:12 +0000 2017
# 30      1748    116094     True  Tue Oct 31 22:07:19 +0000 2017
# 31      2543    116314     True  Tue Oct 31 23:17:22 +0000 2017
# 32      2544    116314     True  Tue Oct 31 22:50:14 +0000 2017
# 33      2547    116314     True  Tue Oct 31 20:19:21 +0000 2017
# 34      2549    116314     True  Tue Oct 31 19:24:59 +0000 2017
# 35      2551    116315     True  Tue Oct 31 22:47:18 +0000 2017
# 36      2555    116317     True  Wed Nov 01 01:55:49 +0000 2017
# 37      2565    116319     True  Tue Oct 31 22:36:21 +0000 2017
# 38      2567    116320     True  Tue Oct 31 22:51:28 +0000 2017
# 39      2570    116321     True  Tue Oct 31 22:16:47 +0000 2017
# 40      2572    116321     True  Tue Oct 31 22:00:12 +0000 2017
# 41      2574    116321     True  Tue Oct 31 21:43:12 +0000 2017
# 42      2579    116322     True  Tue Oct 31 22:50:15 +0000 2017
# 43      2581    116322     True  Tue Oct 31 22:50:46 +0000 2017
# 44      2586    116323     True  Tue Oct 31 20:28:23 +0000 2017
# 45      2590    116325     True  Wed Nov 01 00:03:54 +0000 2017
# 46      2594    116325     True  Tue Oct 31 20:18:44 +0000 2017
# 47      2598    116325     True  Tue Oct 31 19:52:08 +0000 2017
# 48      3723    116610     True  Tue Oct 31 23:19:26 +0000 2017
# 49      3728    116611     True  Tue Oct 31 23:12:06 +0000 2017
# 50      3729    116611     True  Tue Oct 31 22:34:33 +0000 2017
# 51      3748    116617     True  Tue Oct 31 23:02:35 +0000 2017
# 52      3751    116617     True  Wed Nov 01 09:36:48 +0000 2017
# 53      3753    116617     True  Wed Nov 01 10:09:20 +0000 2017
# 54      3756    116617     True  Thu Nov 02 10:31:10 +0000 2017
# 55      4788    116830     True  Tue Oct 31 23:18:00 +0000 2017
# 56      4833    116847     True  Wed Nov 01 00:01:42 +0000 2017
# 57      4847    116849     True  Wed Nov 01 02:12:48 +0000 2017
# 58      4848    116849     True  Wed Nov 01 02:14:56 +0000 2017
# 59      4849    116849     True  Thu Nov 02 15:04:55 +0000 2017
#
#                                                  text
# 0   @AmazonHelp 3 different people have given 3 di...
# 1   @AmazonHelp I frankly don't have the patience ...
# 2                  @AmazonHelp Hi ready for some help
# 3   @AmazonHelp Is the Echo Show no longer supported?
# 4   @AmazonHelp Nothing there helped me with the E...
# 5   .@AmazonHelp Item has not been delivered but t...
# 6   @AmazonHelp I don't want a form to fill out th...
# 7   @AmazonHelp Already started the return. UPS ge...
# 8   @AmazonHelp Is it possible to prevent AMZL fro...
# 9   @AmazonHelp Already handled, just venting. It ...
# 10         @AmazonHelp Aww your reply made her night!
# 11  @AmazonHelp I just said it's been sorted! I've...
# 12            @AmazonHelp Details sent. Please check.
# 13  @AmazonHelp Already contacted 3-4 times in the...
# 14  @115850 @115821 @AmazonHelp @115851 Order# 363...
# 15  @AmazonHelp since when you stop giving 20% off...
# 16  @AmazonHelp Thanks for quick response. Pic att...
# 17  @AmazonHelp Thats the thing I told customer se...
# 18  @AmazonHelp You have to log in. I don't rememb...
# 19  @AmazonHelp They sent me the email I sent you ...
# 20  @AmazonHelp I tried my phone number but I didn...
# 21  @AmazonHelp I called customer service and was ...
# 22  @AmazonHelp where can I chat with a support me...
# 23  @AmazonHelp if I add another adult to my Amazo...
# 24  @AmazonHelp My package just got here. All good...
# 25  @AmazonHelp Star Wars Battlefront 2 Elite Troo...
# 26  @AmazonHelp So to get this straight. I get not...
# 27  @AmazonHelp Already have and the assistance I ...
# 28  Two fake items in one day. Time to cancel my A...
# 29                       @AmazonHelp I have. No luck.
# 30  @AmazonHelp that is not my apartment!!!!!!! Th...
# 31  @AmazonHelp Just now, don't use Amazon much so...
# 32  @AmazonHelp Wasn't tracked as sent via Royal M...
# 33  @AmazonHelp Yeah I sent you a DM too. Had an e...
# 34  @AmazonHelp Hi, I ordered an item on 18 Oct wh...
# 35  @AmazonHelp I'm learning German, so I don't re...
# 36  @AmazonHelp I allowed it well past 8 PM. I was...
# 37  @AmazonHelp Where is my order? https://t.co/pX...
# 38  @AmazonHelp Bummer! I was hoping to get it qui...
# 39  @AmazonHelp yes i did,but amazonuk is not doin...
# 40  @AmazonHelp i mailed amazonuk so many time. bu...
# 41  @AmazonHelp and redund issued on 13th https://...
# 42  @AmazonHelp legacy "shared prime benefits" acc...
# 43  @AmazonHelp I've been in the prime queue, kind...
# 44  @116324 not dlvd after 1 wk. U lied 2 @AmazonH...
# 45  @AmazonHelp So I see that Amazon Twitter is st...
# 46  @AmazonHelp Want to speak to someone at corp t...
# 47  @AmazonHelp Multiple calls to call amazon call...
# 48   @AmazonHelp Have completed form and emailed you.
# 49                            @AmazonHelp All of them
# 50  @AmazonHelp i reset my password 3 times and it...
# 51  @AmazonHelp Many times, but still failing, and...
# 52                              @AmazonHelp Sadly yes
# 53              @AmazonHelp Mac book pro, with Chrome
# 54  @AmazonHelp I need to change the language of m...
# 55  So sad @AmazonHelp @115830 ruined his FIRST Ha...
# 56  @AmazonHelp Thanks!  It was only a little awkw...
# 57  @AmazonHelp will i loose my account? Already t...
# 58  @AmazonHelp will i loose my account?I've tried...
# 59  @AmazonHelp how is Amazon going to solve this?...

# %% [markdown]
# ### Further detection of the non English language

# %% [markdown]
# Now we can see the japanese tweets are dropped after running the function.
# However, there are still German, Spanish tweets in the subset.
# For example : on index 50 'Ach schau an. Meine Bestellung war unzustellba...'
#
# since the dataset is large, to further confirm if all of the non english
# I will use a libray called `langdetect` to detect the non english language.
#
# https://pypi.org/project/langdetect/

# %%
#test on the subset 

non_eng=[]
for x in amazon_sample['text']:
    if detect(x) != 'en':
        non_eng.append(x)
    else:
        continue

# %%
#checking the non english tweets
non_eng
# Out:
# ['@AmazonHelp Where is my order? https://t.co/pXnKSCo2ex',
#  '@AmazonHelp Sadly yes']

# %%
lang = detect('Sadly yes')
lang
# Out:
# 'tr'

# %% [markdown]
# __Short summay from language detect:__
#
# Here we can see that the tweets 'Sadly yes' are actually an English tweets but was mis-dectected as tr(Turkish). It seems not quite accurate.
#
# At this stage, I will use the for loop to filter out every non english tweet on Amazon first
# then I will run this language detect again after the data cleaning or looking for other way to further check on non English tweets

# %% [markdown]
# ### Filter out non english tweet

# %%
#use for loor to filiter out every non english tweet on Amazon
#fliter non english on the sample data

y = 0
for _ in amazon_request['text']:
    if re.search('[^\x00-\x7F]',amazon_request['text'][y]) == None:    # [^\x00-\x7F] is to filter non ascii 
        y = y+1
    else:
        amazon_request.drop(index = y, inplace = True)
        y = y+1 
        continue
amazon_request.reset_index(drop=True, inplace=True)

# %%
#check duplicate based on 'text_x' content i.e the requests from twitter users 
amazon_request[amazon_request.duplicated(['text'])].shape
# Out:
# (3328, 5)

# %%
amazon_request.shape
# Out:
# (97011, 5)

# %%
#drop the duplicate 
amazon_request.drop_duplicates(subset='text',inplace=True)

# %%
#reset the index of the new dateframe 
amazon_request = amazon_request.reset_index(drop=True)

# %%
#shape after dropping duplicate 
amazon_request.shape
# Out:
# (93683, 5)

# %%
amazon_request.head(10)
# Out:
#    tweet_id author_id  inbound                      created_at  \
# 0       616    115820     True  Tue Oct 31 23:22:08 +0000 2017
# 1       619    115820     True  Tue Oct 31 23:32:26 +0000 2017
# 2       638    115834     True  Tue Oct 31 22:19:56 +0000 2017
# 3       640    115834     True  Tue Oct 31 01:03:01 +0000 2017
# 4       641    115834     True  Tue Oct 31 01:02:39 +0000 2017
# 5       646    115835     True  Tue Oct 31 21:40:30 +0000 2017
# 6       651    115838     True  Tue Oct 31 22:25:58 +0000 2017
# 7       654    115838     True  Tue Oct 31 22:53:50 +0000 2017
# 8       652    115838     True  Tue Oct 31 22:11:15 +0000 2017
# 9       657    115839     True  Tue Oct 31 22:18:42 +0000 2017
#
#                                                 text
# 0  @AmazonHelp 3 different people have given 3 di...
# 1  @AmazonHelp I frankly don't have the patience ...
# 2                 @AmazonHelp Hi ready for some help
# 3  @AmazonHelp Is the Echo Show no longer supported?
# 4  @AmazonHelp Nothing there helped me with the E...
# 5  .@AmazonHelp Item has not been delivered but t...
# 6  @AmazonHelp I don't want a form to fill out th...
# 7  @AmazonHelp Already started the return. UPS ge...
# 8  @AmazonHelp Is it possible to prevent AMZL fro...
# 9  @AmazonHelp Already handled, just venting. It ...

# %%
data_explore(amazon_request)
# Out:
# First five rows of data:
#    tweet_id author_id  inbound                      created_at  \
# 0       616    115820     True  Tue Oct 31 23:22:08 +0000 2017
# 1       619    115820     True  Tue Oct 31 23:32:26 +0000 2017
# 2       638    115834     True  Tue Oct 31 22:19:56 +0000 2017
# 3       640    115834     True  Tue Oct 31 01:03:01 +0000 2017
# 4       641    115834     True  Tue Oct 31 01:02:39 +0000 2017
#
#                                                 text
# 0  @AmazonHelp 3 different people have given 3 di...
# 1  @AmazonHelp I frankly don't have the patience ...
# 2                 @AmazonHelp Hi ready for some help
# 3  @AmazonHelp Is the Echo Show no longer supported?
# 4  @AmazonHelp Nothing there helped me with the E...
# Shape: (93683, 5)
#
# Columns & Datatypes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93683 entries, 0 to 93682
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweet_id    93683 non-null  int64
#  1   author_id   93683 non-null  object
#  2   inbound     93683 non-null  bool
#  3   created_at  93683 non-null  object
#  4   text        93683 non-null  object
# dtypes: bool(1), int64(1), object(3)
# memory usage: 2.9+ MB
#
# Null values:
# None in Dataframe.
#
# Unique values (by Columns)
# tweet_id:93683
# author_id:36107
# inbound:1
# created_at:92722
# text:93683

# %%
#export to csv, avoid runing the non english function every time
amazon_request.to_csv('./datasets/amazon_request_en.csv', index=False)
